# %%
using Pkg
Pkg.activate(".") 
Pkg.status()
# Out:
#   Activating project at `~/Projects/Lab-CA-SS26/Lab-CA-SS26-resources`
# Status `~/Projects/Lab-CA-SS26/Lab-CA-SS26-resources/Project.toml`
#   [86223c79] Graphs v1.14.0
